# %%
#|default_exp app
# !pip install -Uqq fastai gradio

# %% [markdown]
# # What type of bear?

# %%
#|export
from fastai.vision.all import *
import gradio as gr

# %%
im = PILImage.create('grizzly.jpg')
im.thumbnail((192,192))
im
# Out:
# PILImage mode=RGB size=192x128

# %%
#|export
learn = load_learner('model.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 #|export
# ----> 2 learn = load_learner('model.pkl')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/fastai/learner.py:446, in load_learner(fname, cpu, pickle_module)
#     444 distrib_barrier()
#     445 map_loc = 'cpu' if cpu else default_device()
# --> 446 try: res = torch.load(fname, map_location=map_loc, pickle_module=pickle_module)
#     447 except AttributeError as e:
#     448     e.args = [f"Custom classes or functions exported with your `Learner` not available in namespace.\Re-declare/import before loading:\n\t{e.args[0]}"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1170 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1171 unpickler.persistent_load = persistent_load
# -> 1172 result = unpickler.load()
#    1174 torch._utils._validate_loaded_sparse_tensors()
#    1176 return result
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/serialization.py:1165, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1163         pass
#    1164 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1165 return super().find_class(mod_name, name)
#
# AttributeError: Custom classes or functions exported with your `Learner` not available in namespace.\Re-declare/import before loading:
# 	Can't get attribute 'Resampling' on <module 'PIL.Image' from '/Users/erandasooriyarachchi/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py'>

# %%
learn.predict(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 learn.predict(im)
#
# NameError: name 'learn' is not defined
